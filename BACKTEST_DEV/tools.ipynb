# %%
import betfairlightweight as bflw
from betfairlightweight.filters import market_filter, time_range
import os
from dotenv import load_dotenv
import time
import logging
from pythonjsonlogger import jsonlogger
import pandas as pd

# load .env
load_dotenv()

USERNAME = os.getenv("BETFAIR_USERNAME")
APP_KEY  = os.getenv("BETFAIR_APP_KEY")
PASSWORD = os.getenv("BETFAIR_PASSWORD")

trading = bflw.APIClient(USERNAME, app_key=APP_KEY, password=PASSWORD, cert_files=("certs/client-2048.crt", "certs/client-2048.key"))  # you still need a live session/login
trading.login()


co = trading.betting.list_current_orders()
for o in co.orders:           # ✅ correct
    print(o.bet_id, o.market_id, o.selection_id, o.side, o.status)
# Out:
# 400559749898 1.247342625 228749 BACK EXECUTION_COMPLETE
# 400559761349 1.247342625 228749 LAY EXECUTION_COMPLETE
# 400559779552 1.247342625 228749 LAY EXECUTION_COMPLETE
# 400559991058 1.247359122 239869 BACK EXECUTION_COMPLETE
# 400560117061 1.247342625 228749 BACK EXECUTION_COMPLETE
# 400560420109 1.247370588 73379512 BACK EXECUTION_COMPLETE
# 400561011361 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400561844764 1.247342625 7659 BACK EXECUTION_COMPLETE
# 400561867927 1.247359122 3351854 BACK EXECUTION_COMPLETE
# 400561870492 1.247370588 73379440 BACK EXECUTION_COMPLETE
# 400562099827 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400562106670 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400562244660 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400562540449 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400562678466 1.247342625 228749 BACK EXECUTION_COMPLETE
# 400562686406 1.247342625 228749 LAY EXECUTION_COMPLETE
# 400562720776 1.247342625 228749 LAY EXECUTION_COMPLETE
# 400562744287 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400562756627 1.247342625 228749 LAY EXECUTION_COMPLETE
# 400562944964 1.247370588 73379512 BACK EXECUTION_COMPLETE
# 400562953533 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400563107518 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400563113179 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400563181630 1.247342625 228749 BACK EXECUTION_COMPLETE
# 400563209293 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400563233616 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563306741 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563438345 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563451171 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563577464 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400563580444 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563585611 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400563592251 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563600733 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563620631 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563627565 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563640241 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563646837 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563656290 1.247325747 7337 LAY EXECUTION_COMPLETE
# 400563676874 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563684687 1.247359122 239869 BACK EXECUTION_COMPLETE
# 400563748566 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563752536 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563761219 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563761679 1.247359122 239869 LAY EXECUTION_COMPLETE
# 400563775614 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563781349 1.247342615 87940438 BACK EXECUTION_COMPLETE
# 400563785147 1.247359122 239869 LAY EXECUTION_COMPLETE
# 400563794687 1.247359122 239869 LAY EXECUTION_COMPLETE
# 400563798646 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563802499 1.247325747 7337 BACK EXECUTION_COMPLETE
# 400563807197 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563821917 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563840431 1.247359122 239869 LAY EXECUTION_COMPLETE
# 400563842159 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563847931 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563854312 1.247370588 73379512 LAY EXECUTION_COMPLETE
# 400563858278 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563862162 1.247359122 239869 LAY EXECUTION_COMPLETE
# 400563864538 1.247325747 1006 LAY EXECUTION_COMPLETE
# 400563865947 1.247370588 73379512 BACK EXECUTION_COMPLETE
# 400563927835 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400563982800 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400563991938 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564045923 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564067221 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564145012 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564181508 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564209959 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564277054 1.247325747 1006 BACK EXECUTION_COMPLETE
# 400564348683 1.247342625 228749 BACK EXECUTION_COMPLETE
# 400564374916 1.247342615 87940438 BACK EXECUTION_COMPLETE
# 400564404020 1.247342615 87940438 BACK EXECUTION_COMPLETE

# %%
cleared
