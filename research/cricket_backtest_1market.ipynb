# %%
import pandas as pd
import time
import logging
from pythonjsonlogger import jsonlogger
from flumine import FlumineSimulation, clients
from collections import OrderedDict, deque, defaultdict
from flumine import BaseStrategy
from flumine.order.trade import Trade
from flumine.order.order import OrderStatus
from flumine.order.ordertype import LimitOrder
from flumine.utils import get_price
from logging_setup import build_logger
import random
import time
from datetime import timedelta

# %%
class FlumineStrat(BaseStrategy):
    """
    Example strateg
    """
    def __init__(self, enter_threshold, exit_threshold, order_hold, price_add, log_root, log_level, *a, **k):
        self.log = build_logger(log_root,log_level)  # logs/trades.log, rotated nightly
        super().__init__(name="risk_backfave",*a, **k)
        self.hist = defaultdict(lambda: deque(maxlen=400))  # per runner
        self.enter_threshold = enter_threshold
        self.exit_threshold = exit_threshold
        self.order_hold = order_hold
        self.price_add = price_add
        self.startdt = None
        self._last = {}    # order_id -> last size_matched
        self.rows = []     # collected fills: [market_id, selection_id, time, size, price, side, order_id]
        self.pnl = 0.0     


    def add_market(self, market):
        self.log.info("ADD", market.market_id, market.event_name, market.event_type_id)
    
    def check_market_book(self, market, market_book):
        if market_book.status == "OPEN" and market_book.inplay:
            return True
    
    def _price_now(self, r):
        return r.last_price_traded
    
    def _price_n_secs_ago(self, key, now_dt, n=5):
        cutoff = now_dt - timedelta(seconds=n)
        dq = self.hist.get(key)
        if not dq: return None
        for t,p in reversed(dq):
            if t <= cutoff:
                return p
        return None

    def matched_summary(self, r, market):
        back_total = lay_total = 0.0
        back_weighted = lay_weighted = 0.0
    
        for o in market.blotter:
            if o.selection_id != r.selection_id:
                continue
            m = float(getattr(o, "size_matched", 0) or 0)
            if m <= 0:
                continue
            p = float(getattr(o, "average_price_matched", 0) or 0)
            side = str(getattr(o, "side", "")).upper()
            if "BACK" in side:
                back_total += m
                back_weighted += m * p
            elif "LAY" in side:
                lay_total += m
                lay_weighted += m * p
    
        avg_back = back_weighted / back_total if back_total else 0.0
        avg_lay = lay_weighted / lay_total if lay_total else 0.0
        return back_total, avg_back, lay_total, avg_lay

    def best_prices_for_runner(self, r):
        ex = getattr(r, "ex", None)
        atb = getattr(ex, "available_to_back", []) or []
        atl = getattr(ex, "available_to_lay", []) or []
    
        def _extract(item):
            # handle dict or PriceSize
            if isinstance(item, dict):
                return item.get("price"), item.get("size")
            return getattr(item, "price", None), getattr(item, "size", None)
            
        bb_price, bb_size = _extract(atb[0]) if atb else (None, None)
        bl_price, bl_size = _extract(atl[0]) if atl else (None, None)
        return bb_price, bb_size, bl_price, bl_size

    
    def process_market_book(self, market, market_book):
        try:
            if not self.startdt: self.startdt = market_book.publish_time
            elapsed = market_book.publish_time.timestamp() - self.startdt.timestamp()
            # self.log.debug(f"Process_market_book: {market.event_name} {market.market_id}, time elapsed {elapsed},  publishtime:{market_book.publish_time}")
    
            if elapsed > 1:
                for r in market_book.runners:
                    now_dt = market_book.publish_time
                    context = f"->{now_dt.strftime("%H:%M:%S.") + f"{int(now_dt.microsecond/100000)}"}|{market.market_id}|{r.selection_id}|"
                    back_total, avg_back, lay_total, avg_lay = self.matched_summary(r,market)
                    runner_context = self.get_runner_context(market.market_id, r.selection_id, r.handicap)

                    key = (market.market_id, r.selection_id)
                    p = self._price_now(r)
                    if not p : return
                    self.log.debug(f"Market tick for {context}, price {p}")
                    
                    if p and p < self.enter_threshold:
                        if runner_context.live_trade_count == 0:
                            self.log.info(f"Trigger back trade: {context} placing order, price {p}")
                            back = round(get_price(r.ex.available_to_lay, 0) + self.price_add,2)
                            trade = Trade(market_book.market_id, r.selection_id, r.handicap, self, notes={"entry_px": back})
                            order = trade.create_order(side="BACK", 
                                                       order_type=LimitOrder(back, self.context["stake"])
                                                       )
                            try:
                                market.place_order(order)
                            except Exception as e:
                                self.log.warning(str(e)) 
                            self.log.info({"ORDER PLACED": context, "price":back})
    
                    if p > self.exit_threshold and back_total:
                        bestb, _ , bestl ,_ = self.best_prices_for_runner(r)
                        loss_on_loss_covered_prc = round(lay_total / back_total,2)
                        cover_ratio = 0.3
                        if loss_on_loss_covered_prc < cover_ratio:
                            if runner_context.live_trade_count == 0:
                                self.log.warning(f"Seeing reason to hedge: {context}, ltp {p} \
                                \n back_total:{back_total}, avg_back:{avg_back}, lay_total:{lay_total}, avg_lay:{avg_lay}.\
                        \n Loss Cover Ratio:{lay_total}/{back_total} = {loss_on_loss_covered_prc} : Hedging as ratio < {cover_ratio} \
                        \n Bestback : {bestb} , bestlay : {bestl}")
                                self.hedge_selection(r, market, market_book, p, context, size=2, price=bestl)
                                
        except Exception as e:
            self.log.warning(f"Failed to process market book : {str(e)}")
            
    def hedge_selection(self,r, market, market_book, p, context, size, price):
        try:
            self.log.warning(f"LAY order pre send : {r.selection_id}, hedge size {size}@ hedge price {price}")
            trade = Trade(market_book.market_id, r.selection_id, r.handicap, self)
            order = trade.create_order("LAY", order_type=LimitOrder(price, size))
            market.place_order(order)
            self.log.warning(f"LAY order placed : {context} " )
        except Exception as e:
            self.log.warning(f"Failed send LAY order  : {str(e)}")
            

    def process_orders(self, market, orders):
        for order in orders:
            if order.status == OrderStatus.EXECUTABLE:
                if order.elapsed_seconds and order.elapsed_seconds > self.order_hold:
                     market.cancel_order(order)

    def process_closed_market(self, market, market_book):
        self.pnl = 0.0
        self.log.info(f"Processing closed market: {market.event_name}, {market.market_id}")
        for order in market.blotter:
            self.pnl += order.profit
            self.log.warning(f"Order PNL {order.profit}, av size matched: {order.size_matched} av price matched: {order.average_price_matched}, date_time_created: {order.date_time_created}")
        self.log.warning(f"Total pnl for market:{market.event_name}, {market.market_id}, : PNL :: {self.pnl}")

# %%
def run_once(market, max_order_exposure, max_selection_exposure, stake, enter_threshold, exit_threshold, order_hold, price_add):
    client = clients.SimulatedClient()
    framework = FlumineSimulation(client=client)

    lists =[]
    lists.append(market)
    
    strategy = FlumineStrat(   
        market_filter={"markets": lists},
        max_order_exposure=max_order_exposure,
        max_selection_exposure=max_selection_exposure,
        context={"stake": stake},
        enter_threshold=enter_threshold,
        exit_threshold=exit_threshold,
        order_hold=order_hold,
        price_add=price_add,
        log_root="./logs/backtest/",
        log_level="W")

    framework.add_strategy(strategy)
    framework.run()
    pnl = getattr(strategy, "pnl")
    del framework, client, strategy
    return pnl

# %%
all_bought_data = pd.read_csv("bought_data_catalogue.csv")["path"].tolist()

bought_single = "hist_data/ADVANCED/2025/Feb/12/33524813/1.232245129"
mine_single = "hist_data/self_recorded/2025-10-09/4/1.248809424.jsonl"
use = "hist_data/ADVANCED/2024/Aug/18/33500547/1.231887491"


pnl = run_once(use,
         max_order_exposure=30,
         max_selection_exposure=30,
         stake=2,
         enter_threshold=1.2,
         exit_threshold=5.9, 
         order_hold=17,
         price_add=0.01)

print(pnl)
# Out:
# STDOUT: 2025-10-09 18:28:10,916 WARNING ::  Seeing reason to hedge: ->16:18:52.3|1.231887491|10787826|, ltp 10.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:0.0, avg_lay:0.0.
#  Loss Cover Ratio:0.0/30.0 = 0.0 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 15
# STDOUT: 2025-10-09 18:28:10,917 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 15
# STDOUT: 2025-10-09 18:28:10,918 WARNING ::  LAY order placed : ->16:18:52.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,923 WARNING ::  Seeing reason to hedge: ->16:18:58.4|1.231887491|10787826|, ltp 6.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 5 , bestlay : 15
# STDOUT: 2025-10-09 18:28:10,924 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 15
# STDOUT: 2025-10-09 18:28:10,926 WARNING ::  LAY order placed : ->16:18:58.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,927 WARNING ::  Seeing reason to hedge: ->16:18:59.4|1.231887491|10787826|, ltp 6.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 5 , bestlay : 15
# STDOUT: 2025-10-09 18:28:10,928 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 15
# STDOUT: 2025-10-09 18:28:10,929 WARNING ::  LAY order placed : ->16:18:59.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,932 WARNING ::  Seeing reason to hedge: ->16:19:00.4|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.2 , bestlay : 15
# STDOUT: 2025-10-09 18:28:10,932 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 15
# STDOUT: 2025-10-09 18:28:10,934 WARNING ::  LAY order placed : ->16:19:00.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,935 WARNING ::  Seeing reason to hedge: ->16:19:01.2|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 5 , bestlay : 15
# STDOUT: 2025-10-09 18:28:10,936 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 15
# STDOUT: 2025-10-09 18:28:10,937 WARNING ::  LAY order placed : ->16:19:01.2|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,938 WARNING ::  Seeing reason to hedge: ->16:19:02.3|1.231887491|10787826|, ltp 6.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 5 , bestlay : 15
# STDOUT: 2025-10-09 18:28:10,939 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 15
# STDOUT: 2025-10-09 18:28:10,940 WARNING ::  LAY order placed : ->16:19:02.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,941 WARNING ::  Seeing reason to hedge: ->16:19:03.3|1.231887491|10787826|, ltp 6.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 5 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,942 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,943 WARNING ::  LAY order placed : ->16:19:03.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,945 WARNING ::  Seeing reason to hedge: ->16:19:04.3|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 5 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,946 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,948 WARNING ::  LAY order placed : ->16:19:04.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,950 WARNING ::  Seeing reason to hedge: ->16:19:05.3|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,951 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,952 WARNING ::  LAY order placed : ->16:19:05.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,954 WARNING ::  Seeing reason to hedge: ->16:19:06.2|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.4 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,955 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,956 WARNING ::  LAY order placed : ->16:19:06.2|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,958 WARNING ::  Seeing reason to hedge: ->16:19:07.3|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.4 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,959 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,960 WARNING ::  LAY order placed : ->16:19:07.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,961 WARNING ::  Seeing reason to hedge: ->16:19:08.3|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.4 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,962 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,963 WARNING ::  LAY order placed : ->16:19:08.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,965 WARNING ::  Seeing reason to hedge: ->16:19:09.3|1.231887491|10787826|, ltp 6.4
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.4 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,965 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,967 WARNING ::  LAY order placed : ->16:19:09.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,968 WARNING ::  Seeing reason to hedge: ->16:19:10.3|1.231887491|10787826|, ltp 7.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.4 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,969 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,970 WARNING ::  LAY order placed : ->16:19:10.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,972 WARNING ::  Seeing reason to hedge: ->16:19:11.4|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.2 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,973 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,974 WARNING ::  LAY order placed : ->16:19:11.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,976 WARNING ::  Seeing reason to hedge: ->16:19:12.3|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.2 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,977 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,979 WARNING ::  LAY order placed : ->16:19:12.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,981 WARNING ::  Seeing reason to hedge: ->16:19:13.3|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.2 , bestlay : 7.2
# STDOUT: 2025-10-09 18:28:10,981 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.2
# STDOUT: 2025-10-09 18:28:10,983 WARNING ::  LAY order placed : ->16:19:13.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,984 WARNING ::  Seeing reason to hedge: ->16:19:14.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,985 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,986 WARNING ::  LAY order placed : ->16:19:14.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,988 WARNING ::  Seeing reason to hedge: ->16:19:15.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,988 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,989 WARNING ::  LAY order placed : ->16:19:15.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,991 WARNING ::  Seeing reason to hedge: ->16:19:16.3|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,992 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,993 WARNING ::  LAY order placed : ->16:19:16.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,994 WARNING ::  Seeing reason to hedge: ->16:19:17.3|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,995 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:10,996 WARNING ::  LAY order placed : ->16:19:17.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:10,998 WARNING ::  Seeing reason to hedge: ->16:19:18.3|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:10,999 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,000 WARNING ::  LAY order placed : ->16:19:18.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,002 WARNING ::  Seeing reason to hedge: ->16:19:19.3|1.231887491|10787826|, ltp 6.8
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,002 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,003 WARNING ::  LAY order placed : ->16:19:19.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,005 WARNING ::  Seeing reason to hedge: ->16:19:20.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,007 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,008 WARNING ::  LAY order placed : ->16:19:20.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,010 WARNING ::  Seeing reason to hedge: ->16:19:21.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,011 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,012 WARNING ::  LAY order placed : ->16:19:21.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,014 WARNING ::  Seeing reason to hedge: ->16:19:22.4|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,014 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,015 WARNING ::  LAY order placed : ->16:19:22.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,017 WARNING ::  Seeing reason to hedge: ->16:19:23.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,018 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,019 WARNING ::  LAY order placed : ->16:19:23.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,020 WARNING ::  Seeing reason to hedge: ->16:19:24.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,021 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,022 WARNING ::  LAY order placed : ->16:19:24.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,023 WARNING ::  Seeing reason to hedge: ->16:19:25.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 6.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,024 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,025 WARNING ::  LAY order placed : ->16:19:25.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,027 WARNING ::  Seeing reason to hedge: ->16:19:26.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,028 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,029 WARNING ::  LAY order placed : ->16:19:26.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,030 WARNING ::  Seeing reason to hedge: ->16:19:27.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,031 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,033 WARNING ::  LAY order placed : ->16:19:27.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,035 WARNING ::  Seeing reason to hedge: ->16:19:28.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,035 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,036 WARNING ::  LAY order placed : ->16:19:28.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,038 WARNING ::  Seeing reason to hedge: ->16:19:29.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,038 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,039 WARNING ::  LAY order placed : ->16:19:29.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,042 WARNING ::  Seeing reason to hedge: ->16:19:30.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,042 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,044 WARNING ::  LAY order placed : ->16:19:30.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,046 WARNING ::  Seeing reason to hedge: ->16:19:31.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,047 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,048 WARNING ::  LAY order placed : ->16:19:31.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,050 WARNING ::  Seeing reason to hedge: ->16:19:32.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,051 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,052 WARNING ::  LAY order placed : ->16:19:32.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,053 WARNING ::  Seeing reason to hedge: ->16:19:33.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,054 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,056 WARNING ::  LAY order placed : ->16:19:33.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,058 WARNING ::  Seeing reason to hedge: ->16:19:34.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,059 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,060 WARNING ::  LAY order placed : ->16:19:34.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,063 WARNING ::  Seeing reason to hedge: ->16:19:35.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,065 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,066 WARNING ::  LAY order placed : ->16:19:35.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,067 WARNING ::  Seeing reason to hedge: ->16:19:36.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,068 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,069 WARNING ::  LAY order placed : ->16:19:36.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,071 WARNING ::  Seeing reason to hedge: ->16:19:37.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,071 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,073 WARNING ::  LAY order placed : ->16:19:37.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,074 WARNING ::  Seeing reason to hedge: ->16:19:38.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,075 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,076 WARNING ::  LAY order placed : ->16:19:38.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,077 WARNING ::  Seeing reason to hedge: ->16:19:39.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,078 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,079 WARNING ::  LAY order placed : ->16:19:39.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,081 WARNING ::  Seeing reason to hedge: ->16:19:40.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,081 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,083 WARNING ::  LAY order placed : ->16:19:40.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,084 WARNING ::  Seeing reason to hedge: ->16:19:41.4|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,085 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,086 WARNING ::  LAY order placed : ->16:19:41.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,087 WARNING ::  Seeing reason to hedge: ->16:19:42.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,088 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,089 WARNING ::  LAY order placed : ->16:19:42.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,090 WARNING ::  Seeing reason to hedge: ->16:19:43.4|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,091 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,092 WARNING ::  LAY order placed : ->16:19:43.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,093 WARNING ::  Seeing reason to hedge: ->16:19:44.4|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,094 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,095 WARNING ::  LAY order placed : ->16:19:44.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,096 WARNING ::  Seeing reason to hedge: ->16:19:45.4|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,097 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,098 WARNING ::  LAY order placed : ->16:19:45.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,100 WARNING ::  Seeing reason to hedge: ->16:19:46.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.4 , bestlay : 8
# STDOUT: 2025-10-09 18:28:11,100 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8
# STDOUT: 2025-10-09 18:28:11,102 WARNING ::  LAY order placed : ->16:19:46.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,103 WARNING ::  Seeing reason to hedge: ->16:19:47.2|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,104 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,105 WARNING ::  LAY order placed : ->16:19:47.2|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,106 WARNING ::  Seeing reason to hedge: ->16:19:48.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,106 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,108 WARNING ::  LAY order placed : ->16:19:48.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,109 WARNING ::  Seeing reason to hedge: ->16:19:49.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,110 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,111 WARNING ::  LAY order placed : ->16:19:49.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,112 WARNING ::  Seeing reason to hedge: ->16:19:50.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,113 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,114 WARNING ::  LAY order placed : ->16:19:50.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,115 WARNING ::  Seeing reason to hedge: ->16:19:51.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,116 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,117 WARNING ::  LAY order placed : ->16:19:51.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,118 WARNING ::  Seeing reason to hedge: ->16:19:52.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,119 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,120 WARNING ::  LAY order placed : ->16:19:52.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,121 WARNING ::  Seeing reason to hedge: ->16:19:53.4|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,122 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,123 WARNING ::  LAY order placed : ->16:19:53.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,124 WARNING ::  Seeing reason to hedge: ->16:19:54.3|1.231887491|10787826|, ltp 7.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,125 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,126 WARNING ::  LAY order placed : ->16:19:54.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,127 WARNING ::  Seeing reason to hedge: ->16:19:55.4|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,128 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,129 WARNING ::  LAY order placed : ->16:19:55.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,130 WARNING ::  Seeing reason to hedge: ->16:19:56.3|1.231887491|10787826|, ltp 7.2
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 7.6
# STDOUT: 2025-10-09 18:28:11,131 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 7.6
# STDOUT: 2025-10-09 18:28:11,132 WARNING ::  LAY order placed : ->16:19:56.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,134 WARNING ::  Seeing reason to hedge: ->16:19:57.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 8.4
# STDOUT: 2025-10-09 18:28:11,134 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.4
# STDOUT: 2025-10-09 18:28:11,135 WARNING ::  LAY order placed : ->16:19:57.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,136 WARNING ::  Seeing reason to hedge: ->16:19:58.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 8.4
# STDOUT: 2025-10-09 18:28:11,137 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.4
# STDOUT: 2025-10-09 18:28:11,138 WARNING ::  LAY order placed : ->16:19:58.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,140 WARNING ::  Seeing reason to hedge: ->16:19:59.4|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 8.4
# STDOUT: 2025-10-09 18:28:11,141 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.4
# STDOUT: 2025-10-09 18:28:11,142 WARNING ::  LAY order placed : ->16:19:59.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,143 WARNING ::  Seeing reason to hedge: ->16:20:00.1|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.2 , bestlay : 8.4
# STDOUT: 2025-10-09 18:28:11,144 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.4
# STDOUT: 2025-10-09 18:28:11,145 WARNING ::  LAY order placed : ->16:20:00.1|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,147 WARNING ::  Seeing reason to hedge: ->16:20:01.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.6 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,148 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,149 WARNING ::  LAY order placed : ->16:20:01.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,151 WARNING ::  Seeing reason to hedge: ->16:20:02.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,152 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,154 WARNING ::  LAY order placed : ->16:20:02.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,155 WARNING ::  Seeing reason to hedge: ->16:20:03.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,156 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,158 WARNING ::  LAY order placed : ->16:20:03.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,160 WARNING ::  Seeing reason to hedge: ->16:20:04.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,161 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,164 WARNING ::  LAY order placed : ->16:20:04.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,166 WARNING ::  Seeing reason to hedge: ->16:20:05.2|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,167 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,168 WARNING ::  LAY order placed : ->16:20:05.2|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,170 WARNING ::  Seeing reason to hedge: ->16:20:06.4|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,171 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,171 WARNING ::  LAY order placed : ->16:20:06.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,173 WARNING ::  Seeing reason to hedge: ->16:20:07.4|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,174 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,174 WARNING ::  LAY order placed : ->16:20:07.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,176 WARNING ::  Seeing reason to hedge: ->16:20:08.4|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,177 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,178 WARNING ::  LAY order placed : ->16:20:08.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,179 WARNING ::  Seeing reason to hedge: ->16:20:09.4|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 8.6
# STDOUT: 2025-10-09 18:28:11,180 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 8.6
# STDOUT: 2025-10-09 18:28:11,181 WARNING ::  LAY order placed : ->16:20:09.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,183 WARNING ::  Seeing reason to hedge: ->16:20:10.4|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,183 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,184 WARNING ::  LAY order placed : ->16:20:10.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,186 WARNING ::  Seeing reason to hedge: ->16:20:11.3|1.231887491|10787826|, ltp 8.0
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,187 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,188 WARNING ::  LAY order placed : ->16:20:11.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,189 WARNING ::  Seeing reason to hedge: ->16:20:12.3|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 7.8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,190 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,191 WARNING ::  LAY order placed : ->16:20:12.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,193 WARNING ::  Seeing reason to hedge: ->16:20:13.4|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 8.6 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,193 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,194 WARNING ::  LAY order placed : ->16:20:13.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,196 WARNING ::  Seeing reason to hedge: ->16:20:14.3|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 8 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,196 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,198 WARNING ::  LAY order placed : ->16:20:14.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,199 WARNING ::  Seeing reason to hedge: ->16:20:15.4|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,199 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,200 WARNING ::  LAY order placed : ->16:20:15.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,202 WARNING ::  Seeing reason to hedge: ->16:20:16.4|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,203 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,204 WARNING ::  LAY order placed : ->16:20:16.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,205 WARNING ::  Seeing reason to hedge: ->16:20:17.4|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,206 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,207 WARNING ::  LAY order placed : ->16:20:17.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,208 WARNING ::  Seeing reason to hedge: ->16:20:18.4|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,209 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,211 WARNING ::  LAY order placed : ->16:20:18.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,213 WARNING ::  Seeing reason to hedge: ->16:20:19.4|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,214 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,217 WARNING ::  LAY order placed : ->16:20:19.4|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,218 WARNING ::  Seeing reason to hedge: ->16:20:20.3|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,220 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,221 WARNING ::  LAY order placed : ->16:20:20.3|1.231887491|10787826|
# STDOUT: 2025-10-09 18:28:11,222 WARNING ::  Seeing reason to hedge: ->16:20:21.3|1.231887491|10787826|, ltp 8.6
#  back_total:30.0, avg_back:1.1653333333333333, lay_total:2.0, avg_lay:15.0.
#  Loss Cover Ratio:2.0/30.0 = 0.07 : Hedging as ratio < 0.3
#  Bestback : 3.2 , bestlay : 10
# STDOUT: 2025-10-09 18:28:11,223 WARNING ::  LAY order pre send : 10787826, hedge size 2@ hedge price 10
# STDOUT: 2025-10-09 18:28:11,224 WARNING ::  LAY order placed : ->16:20:21.3|1.231887491|10787826|
# ...
# STDOUT: 2025-10-09 18:28:15,499 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:39:42.347000
# STDOUT: 2025-10-09 18:28:15,500 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:40:07.367000
# STDOUT: 2025-10-09 18:28:15,501 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:40:31.381000
# STDOUT: 2025-10-09 18:28:15,501 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:40:56.410000
# STDOUT: 2025-10-09 18:28:15,502 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:41:20.321000
# STDOUT: 2025-10-09 18:28:15,503 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:41:45.262000
# STDOUT: 2025-10-09 18:28:15,504 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:42:09.363000
# STDOUT: 2025-10-09 18:28:15,504 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:42:33.403000
# STDOUT: 2025-10-09 18:28:15,505 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:43:03.044000
# STDOUT: 2025-10-09 18:28:15,506 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:43:26.406000
# STDOUT: 2025-10-09 18:28:15,507 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:43:51.437000
# STDOUT: 2025-10-09 18:28:15,507 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:44:15.435000
# STDOUT: 2025-10-09 18:28:15,508 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:45:29.333000
# STDOUT: 2025-10-09 18:28:15,509 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:45:55.254000
# STDOUT: 2025-10-09 18:28:15,510 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:46:21.390000
# STDOUT: 2025-10-09 18:28:15,510 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:46:47.234000
# STDOUT: 2025-10-09 18:28:15,511 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:47:16.063000
# STDOUT: 2025-10-09 18:28:15,512 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:47:51.406000
# STDOUT: 2025-10-09 18:28:15,512 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:48:17.416000
# STDOUT: 2025-10-09 18:28:15,513 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:48:48.294000
# STDOUT: 2025-10-09 18:28:15,514 WARNING ::  Order PNL -2, av size matched: 2 av price matched: 1.21, date_time_created: 2024-08-18 10:49:19.377000
# STDOUT: 2025-10-09 18:28:15,514 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:54:27.378000
# STDOUT: 2025-10-09 18:28:15,515 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:54:52.283000
# STDOUT: 2025-10-09 18:28:15,515 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:55:17.436000
# STDOUT: 2025-10-09 18:28:15,516 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:55:41.230000
# STDOUT: 2025-10-09 18:28:15,516 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:56:06.274000
# STDOUT: 2025-10-09 18:28:15,517 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:56:30.403000
# STDOUT: 2025-10-09 18:28:15,517 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:56:53.904000
# STDOUT: 2025-10-09 18:28:15,518 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:57:17.382000
# STDOUT: 2025-10-09 18:28:15,519 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:57:42.356000
# STDOUT: 2025-10-09 18:28:15,519 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:58:07.398000
# STDOUT: 2025-10-09 18:28:15,520 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:58:31.340000
# STDOUT: 2025-10-09 18:28:15,521 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:58:56.309000
# STDOUT: 2025-10-09 18:28:15,521 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:59:20.434000
# STDOUT: 2025-10-09 18:28:15,522 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 10:59:44.357000
# STDOUT: 2025-10-09 18:28:15,522 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:00:09.401000
# STDOUT: 2025-10-09 18:28:15,523 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:00:34.295000
# STDOUT: 2025-10-09 18:28:15,524 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:00:58.433000
# STDOUT: 2025-10-09 18:28:15,524 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:01:22.372000
# STDOUT: 2025-10-09 18:28:15,525 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:01:46.409000
# STDOUT: 2025-10-09 18:28:15,526 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:02:11.436000
# STDOUT: 2025-10-09 18:28:15,527 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:02:36.367000
# STDOUT: 2025-10-09 18:28:15,528 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:03:01.393000
# STDOUT: 2025-10-09 18:28:15,529 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:03:27.323000
# STDOUT: 2025-10-09 18:28:15,530 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:03:52.238000
# STDOUT: 2025-10-09 18:28:15,530 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:04:16.761000
# STDOUT: 2025-10-09 18:28:15,531 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:04:41.394000
# STDOUT: 2025-10-09 18:28:15,531 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:05:05.201000
# STDOUT: 2025-10-09 18:28:15,532 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:05:29.349000
# STDOUT: 2025-10-09 18:28:15,533 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:05:53.670000
# STDOUT: 2025-10-09 18:28:15,534 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:06:18.301000
# STDOUT: 2025-10-09 18:28:15,534 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:06:43.229000
# STDOUT: 2025-10-09 18:28:15,535 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:07:09.159000
# STDOUT: 2025-10-09 18:28:15,536 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:07:33.407000
# STDOUT: 2025-10-09 18:28:15,536 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:07:57.427000
# STDOUT: 2025-10-09 18:28:15,537 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:08:21.436000
# STDOUT: 2025-10-09 18:28:15,537 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:08:46.156000
# STDOUT: 2025-10-09 18:28:15,538 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:09:08.968000
# STDOUT: 2025-10-09 18:28:15,539 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:09:33.332000
# STDOUT: 2025-10-09 18:28:15,539 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:09:58.411000
# STDOUT: 2025-10-09 18:28:15,540 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:10:23.163000
# STDOUT: 2025-10-09 18:28:15,541 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:10:46.393000
# STDOUT: 2025-10-09 18:28:15,541 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:11:11.295000
# STDOUT: 2025-10-09 18:28:15,542 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:11:35.030000
# STDOUT: 2025-10-09 18:28:15,543 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:11:59.267000
# STDOUT: 2025-10-09 18:28:15,543 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:12:24.206000
# STDOUT: 2025-10-09 18:28:15,544 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:12:49.421000
# STDOUT: 2025-10-09 18:28:15,545 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:13:13.013000
# STDOUT: 2025-10-09 18:28:15,545 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:13:36.427000
# STDOUT: 2025-10-09 18:28:15,546 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:14:00.263000
# STDOUT: 2025-10-09 18:28:15,546 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:14:24.321000
# STDOUT: 2025-10-09 18:28:15,547 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:14:50.341000
# STDOUT: 2025-10-09 18:28:15,548 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:15:15.239000
# STDOUT: 2025-10-09 18:28:15,549 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:15:40.386000
# STDOUT: 2025-10-09 18:28:15,549 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:16:04.400000
# STDOUT: 2025-10-09 18:28:15,550 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:16:32.148000
# STDOUT: 2025-10-09 18:28:15,550 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:16:56.280000
# STDOUT: 2025-10-09 18:28:15,551 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:17:34.389000
# STDOUT: 2025-10-09 18:28:15,552 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:18:04.340000
# STDOUT: 2025-10-09 18:28:15,553 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:18:36.387000
# STDOUT: 2025-10-09 18:28:15,553 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:19:00.304000
# STDOUT: 2025-10-09 18:28:15,554 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:19:25.418000
# STDOUT: 2025-10-09 18:28:15,555 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:19:49.297000
# STDOUT: 2025-10-09 18:28:15,555 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:20:18.371000
# STDOUT: 2025-10-09 18:28:15,556 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:20:43.420000
# STDOUT: 2025-10-09 18:28:15,557 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:21:08.371000
# STDOUT: 2025-10-09 18:28:15,557 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:21:32.366000
# STDOUT: 2025-10-09 18:28:15,558 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:21:56.082000
# STDOUT: 2025-10-09 18:28:15,559 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:22:20.311000
# STDOUT: 2025-10-09 18:28:15,559 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:22:45.414000
# STDOUT: 2025-10-09 18:28:15,560 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:23:14.082000
# STDOUT: 2025-10-09 18:28:15,561 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:23:48.440000
# STDOUT: 2025-10-09 18:28:15,561 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:24:13.384000
# STDOUT: 2025-10-09 18:28:15,562 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:24:37.300000
# STDOUT: 2025-10-09 18:28:15,563 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:25:03.330000
# STDOUT: 2025-10-09 18:28:15,563 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:25:28.270000
# STDOUT: 2025-10-09 18:28:15,564 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:25:53.280000
# STDOUT: 2025-10-09 18:28:15,565 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:26:19.306000
# STDOUT: 2025-10-09 18:28:15,565 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:26:44.331000
# STDOUT: 2025-10-09 18:28:15,566 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:27:08.190000
# STDOUT: 2025-10-09 18:28:15,567 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:27:32.379000
# STDOUT: 2025-10-09 18:28:15,568 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:27:58.420000
# STDOUT: 2025-10-09 18:28:15,568 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:28:57.409000
# STDOUT: 2025-10-09 18:28:15,569 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:30:03.266000
# STDOUT: 2025-10-09 18:28:15,570 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:30:27.420000
# STDOUT: 2025-10-09 18:28:15,570 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:31:56.409000
# STDOUT: 2025-10-09 18:28:15,571 WARNING ::  Order PNL -2.0, av size matched: 2.0 av price matched: 1.2, date_time_created: 2024-08-18 11:32:21.215000
# STDOUT: 2025-10-09 18:28:15,572 WARNING ::  Order PNL 0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2024-08-18 11:32:42.334000
