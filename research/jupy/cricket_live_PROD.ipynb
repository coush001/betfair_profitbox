# %%
import warnings
warnings.filterwarnings("ignore")
import sys
sys.stderr = open('./logs/live_prod/error.log', 'w')

import pandas as pd
import time
import logging
from pythonjsonlogger import jsonlogger
from flumine import FlumineSimulation, clients
from collections import OrderedDict, deque, defaultdict
from flumine import BaseStrategy
from flumine.order.trade import Trade
from flumine.order.order import OrderStatus
from flumine.order.ordertype import LimitOrder
from flumine.utils import get_price
from logging_setup import build_logger
import random

import time
from datetime import timedelta
import betfairlightweight as bflw
from flumine import Flumine, clients, BaseStrategy
from betfairlightweight.filters import streaming_market_filter, streaming_market_data_filter
from flumine import Flumine, clients

import os
from dotenv import load_dotenv
import time
import logging
from pythonjsonlogger import jsonlogger
import pandas as pd
from betfairlightweight.filters import market_filter
import logging
from pythonjsonlogger import jsonlogger


class HugoStrat(BaseStrategy):
    """
    Example strateg
    """
    def __init__(self, enter_threshold, exit_threshold, order_hold, price_add, log_root, log_level, *a, **k):
        self.log = build_logger(log_root,log_level)  # logs/trades.log, rotated nightly
        super().__init__(*a, **k)
        self.hist = defaultdict(lambda: deque(maxlen=400))  # per runner
        self.enter_threshold = enter_threshold
        self.exit_threshold = exit_threshold
        self.order_hold = order_hold
        self.price_add = price_add
        # self.dev = dev
        # self.lookback = lookback
        # self.take_prof_price_diff = take_prof_price_diff
        self.startdt = None
        self._last = {}    # order_id -> last size_matched
        self.rows = []     # collected fills: [market_id, selection_id, time, size, price, side, order_id]
        self.pnl = 0.0     


    def add_market(self, market):
        self.log.info("ADD", market.market_id, market.event_name, market.event_type_id)
    
    def check_market_book(self, market, market_book):
        if market_book.status == "OPEN" and market_book.inplay:
            return True
    
    def _price_now(self, r):
        return r.last_price_traded
    
    def _price_n_secs_ago(self, key, now_dt, n=5):
        cutoff = now_dt - timedelta(seconds=n)
        dq = self.hist.get(key)
        if not dq: return None
        # find the latest sample at/before cutoff
        for t,p in reversed(dq):
            if t <= cutoff:
                return p
        return None

    def avg_back_odds(self, market, selection_id):
        total_stake, weighted = 0, 0
        for order in market.blotter:
            if order.selection_id == selection_id and order.side == "BACK":
                matched = order.size_matched
                if matched > 0:
                    total_stake += matched
                    weighted += matched * order.average_price_matched
        return weighted / total_stake if total_stake else None
    
    def process_market_book(self, market, market_book):
        if not self.startdt: self.startdt = market_book.publish_time
        elapsed = market_book.publish_time.timestamp() - self.startdt.timestamp()
        self.log.debug(f"process_market_book: {market.event_name}, time elapse {elapsed},  publishtime:{market_book.publish_time}")

# wait until 1 hour done then hedge out
        if elapsed > 1:
            self.log.debug(f"elapsed time {elapsed} > 3200, place bets return")
            for r in market_book.runners:
                now_dt = market_book.publish_time  # simulation “now”
                key = (market.market_id, r.selection_id)
                p = self._price_now(r)
                if p and p < self.enter_threshold:
                    runner_context = self.get_runner_context(market.market_id, r.selection_id, r.handicap)
                    if runner_context.live_trade_count == 0:
                        self.log.info(f"price less than thresh, no live trades, placing order: {r.selection_id}")
                        # back at current best lay price
                        back = round(get_price(r.ex.available_to_lay, 0) + self.price_add,2)
                        # create trade
                        trade = Trade(market_book.market_id, r.selection_id, r.handicap,self, notes={"entry_px": back})
                        order = trade.create_order(side="BACK", order_type=LimitOrder(back, self.context["stake"]))
                        market.place_order(order)
                        self.log.info({"PLACE ORDER":market.market_id,"price":back,"event_name":market.event_name})

                if not p : return
                if p > self.exit_threshold:
                    self.hedge_selection(r, market)

    def avg_back_odds(self, market, selection_id):
        total_stake, weighted = 0, 0
        for order in market.blotter:
            if order.selection_id == selection_id and order.side == "BACK":
                matched = order.size_matched
                if matched > 0:
                    total_stake += matched
                    weighted += matched * order.average_price_matched
        return weighted / total_stake if total_stake else None
    
    def hedge_selection(self,r, market):        
        backs = [o for o in market.blotter if o.selection_id==r.selection_id and o.side=="BACK" and o.size_matched>0]
        stake = sum(o.size_matched for o in backs)
        best_lay = get_price(r.ex.available_to_lay, 0)
        if not best_lay: return
        av = self.avg_back_odds(market, r.selection_id)
        if not av: return
        # hedge size so Pwin == Plose
        hsize = (av*stake - stake) / best_lay
        if hsize <= 0: return
        self.log.info(f"Closing risk : runner {r.selection_id}, {hsize} @ {best_lay}")
        trade = Trade(market.market_id, r.selection_id, r.handicap, self)
        order = trade.create_order("LAY", LimitOrder(best_lay, round(hsize,2), persistence_type="LAPSE"))
        market.place_order(order)
 
    
    def process_orders(self, market, orders):
        # kill order if unmatched in market for greater than 2 seconds
        for order in orders:
            if order.status == OrderStatus.EXECUTABLE:
                if order.elapsed_seconds and order.elapsed_seconds > self.order_hold:
                     market.cancel_order(order)

    def process_order(self, order):
        # fully matched
        if order.status == OrderStatus.EXECUTION_COMPLETE:
            a = {"Order fully matched": order.selection_id,"avg_px":order.average_price_matched,
                 "size":order.size_matched}
            self.log.info(a)

        # partially matched
        elif order.size_matched and order.size_remaining:
            a = {"Partial match":order.selection_id,
                 "matched":order.size_matched,
                 "remaining":order.size_remaining,
                 "avg_px":order.average_price_matched}
            self.log.info(a)

    def process_closed_market(self, market, market_book):
        self.pnl = 0.0
        self.log.info(f"Processing closed market: {market.event_name}, {market.market_id}")
        for order in market.blotter:
            self.pnl += order.profit
            self.log.info(f"Order PNL {order.profit}, av size matched: {order.size_matched} av price matched: {order.average_price_matched}, date_time_created: {order.date_time_created}")
            
        self.log.warning(f"Total pnl for market:{market.event_name}, {market.market_id}, : PNL :: {self.pnl}")
            
    
# load .env
load_dotenv(dotenv_path="")

USERNAME = os.getenv("BETFAIR_USERNAME")
APP_KEY  = os.getenv("BETFAIR_APP_KEY")
PASSWORD = os.getenv("BETFAIR_PASSWORD")


trading = bflw.APIClient(USERNAME, app_key=APP_KEY, password=PASSWORD, cert_files=("certs/client-2048.crt", "certs/client-2048.key"))  # you still need a live session/login
trading.login()


market = market_filter(
    event_type_ids=["4"],     # 4 = Cricket
    market_type_codes=["MATCH_ODDS"],
    market_countries=["GB", "IN"],
)

catalogues = trading.betting.list_market_catalogue(
    filter=market,
    max_results=100,
    market_projection=["MARKET_START_TIME","RUNNER_DESCRIPTION","EVENT"]
)

for m in catalogues:
    print(m.json())
    for r in m.runners:
        print("  ", r.selection_id, r.runner_name)

# Only cricket (eventTypeId = 4)
flt = market_filter(event_type_ids=["4"])
countries = trading.betting.list_countries(filter=flt)

for c in countries:
    print(c.country_code, c.market_count)


logger = logging.getLogger()
custom_format = "%(asctime) %(levelname) %(message)"
log_handler = logging.StreamHandler()
formatter = jsonlogger.JsonFormatter(custom_format)
formatter.converter = time.gmtime
log_handler.setFormatter(formatter)
logger.addHandler(log_handler)
logger.setLevel(logging.WARN)  # Set to logging.CRITICAL to speed up simulation

client  = clients.BetfairClient(trading, paper_trade=False)
framework = Flumine(client)

strategy = HugoStrat(   
        market_filter=market,
        max_order_exposure=30,
        max_selection_exposure=90,
        context={"stake": 2},
        enter_threshold=1.2,
        exit_threshold=5.9,
        order_hold=17,
        price_add=0.01,
        log_root="./logs/live_prod/",
        log_level="I")

framework.add_strategy(strategy)
framework.run()
# Out:
# b'{"marketId":"1.247721170","marketName":"Match Odds","marketStartTime":"2025-09-14T08:00:00.000Z","totalMatched":14918086.55,"runners":[{"selectionId":83500062,"runnerName":"India W","handicap":0.0,"sortPriority":1},{"selectionId":10987516,"runnerName":"Australia W","handicap":0.0,"sortPriority":2}],"event":{"id":"34711985","name":"India W v Australia W","countryCode":"GB","timezone":"GMT","openDate":"2025-09-14T08:00:00.000Z"}}'
#    83500062 India W
#    10987516 Australia W
# b'{"marketId":"1.247589862","marketName":"Match Odds","marketStartTime":"2025-09-14T09:30:00.000Z","totalMatched":192549.46,"runners":[{"selectionId":82681068,"runnerName":"Glamorgan W","handicap":0.0,"sortPriority":1},{"selectionId":82867854,"runnerName":"Yorkshire W","handicap":0.0,"sortPriority":2}],"event":{"id":"34712222","name":"Glamorgan W v Yorkshire W","countryCode":"GB","timezone":"GMT","openDate":"2025-09-14T09:30:00.000Z"}}'
#    82681068 Glamorgan W
#    82867854 Yorkshire W
# b'{"marketId":"1.247708504","marketName":"Match Odds","marketStartTime":"2025-09-14T13:30:00.000Z","totalMatched":88658.75,"runners":[{"selectionId":10301,"runnerName":"England","handicap":0.0,"sortPriority":1},{"selectionId":349,"runnerName":"South Africa","handicap":0.0,"sortPriority":2}],"event":{"id":"34726614","name":"England v South Africa","countryCode":"GB","timezone":"GMT","openDate":"2025-09-14T13:30:00.000Z"}}'
#    10301 England
#    349 South Africa
# b'{"marketId":"1.247693476","marketName":"Match Odds","marketStartTime":"2025-09-14T14:30:00.000Z","totalMatched":1823927.78,"runners":[{"selectionId":414464,"runnerName":"India","handicap":0.0,"sortPriority":1},{"selectionId":7461,"runnerName":"Pakistan","handicap":0.0,"sortPriority":2}],"event":{"id":"34726538","name":"India v Pakistan","countryCode":"GB","timezone":"GMT","openDate":"2025-09-14T14:30:00.000Z"}}'
#    414464 India
#    7461 Pakistan
# b'{"marketId":"1.247765236","marketName":"Match Odds","marketStartTime":"2025-09-14T18:00:00.000Z","totalMatched":2078.15,"runners":[{"selectionId":47674068,"runnerName":"Guyana Amazon Warriors W","handicap":0.0,"sortPriority":1},{"selectionId":47650821,"runnerName":"Barbados Royals Women","handicap":0.0,"sortPriority":2}],"event":{"id":"34730322","name":"Guyana Amazon Warriors W v Barbados Royals Women","countryCode":"GB","timezone":"GMT","openDate":"2025-09-14T18:00:00.000Z"}}'
#    47674068 Guyana Amazon Warriors W
#    47650821 Barbados Royals Women
# b'{"marketId":"1.247754234","marketName":"Match Odds","marketStartTime":"2025-09-14T23:00:00.000Z","totalMatched":877.55,"runners":[{"selectionId":7591770,"runnerName":"Guyana Amazon Warriors","handicap":0.0,"sortPriority":1},{"selectionId":40497467,"runnerName":"Barbados Royals","handicap":0.0,"sortPriority":2}],"event":{"id":"34730243","name":"Guyana Amazon Warriors v Barbados Royals","countryCode":"GB","timezone":"GMT","openDate":"2025-09-14T23:00:00.000Z"}}'
#    7591770 Guyana Amazon Warriors
#    40497467 Barbados Royals
# b'{"marketId":"1.247613813","marketName":"Match Odds","marketStartTime":"2025-09-15T04:00:00.000Z","totalMatched":12041.81,"runners":[{"selectionId":7812768,"runnerName":"South Zone","handicap":0.0,"sortPriority":1},{"selectionId":8390083,"runnerName":"Central Zone","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34712158","name":"South Zone v Central Zone","countryCode":"GB","timezone":"Europe/London","openDate":"2025-09-15T04:00:00.000Z"}}'
#    7812768 South Zone
#    8390083 Central Zone
#    60443 The Draw
# b'{"marketId":"1.247664624","marketName":"Match Odds","marketStartTime":"2025-09-15T09:30:00.000Z","totalMatched":0.0,"runners":[{"selectionId":31374,"runnerName":"Durham","handicap":0.0,"sortPriority":1},{"selectionId":31372,"runnerName":"Worcestershire","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34723445","name":"Durham v Worcestershire","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T09:30:00.000Z"}}'
#    31374 Durham
#    31372 Worcestershire
#    60443 The Draw
# b'{"marketId":"1.247667545","marketName":"Match Odds","marketStartTime":"2025-09-15T09:30:00.000Z","totalMatched":0.0,"runners":[{"selectionId":424679,"runnerName":"Lancashire","handicap":0.0,"sortPriority":1},{"selectionId":31378,"runnerName":"Middlesex","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34723642","name":"Lancashire v Middlesex","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T09:30:00.000Z"}}'
#    424679 Lancashire
#    31378 Middlesex
#    60443 The Draw
# b'{"marketId":"1.247668363","marketName":"Match Odds","marketStartTime":"2025-09-15T09:30:00.000Z","totalMatched":22.78,"runners":[{"selectionId":2219,"runnerName":"Gloucestershire","handicap":0.0,"sortPriority":1},{"selectionId":475559,"runnerName":"Northamptonshire","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34723778","name":"Gloucestershire v Northamptonshire","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T09:30:00.000Z"}}'
#    2219 Gloucestershire
#    475559 Northamptonshire
#    60443 The Draw
# b'{"marketId":"1.247664099","marketName":"Match Odds","marketStartTime":"2025-09-15T09:30:00.000Z","totalMatched":0.0,"runners":[{"selectionId":31377,"runnerName":"Leicestershire","handicap":0.0,"sortPriority":1},{"selectionId":5901,"runnerName":"Kent","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34723050","name":"Leicestershire v Kent","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T09:30:00.000Z"}}'
#    31377 Leicestershire
#    5901 Kent
#    60443 The Draw
# b'{"marketId":"1.247664097","marketName":"Match Odds","marketStartTime":"2025-09-15T09:30:00.000Z","totalMatched":0.0,"runners":[{"selectionId":31375,"runnerName":"Derbyshire","handicap":0.0,"sortPriority":1},{"selectionId":169,"runnerName":"Glamorgan","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34723056","name":"Derbyshire v Glamorgan","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T09:30:00.000Z"}}'
#    31375 Derbyshire
#    169 Glamorgan
#    60443 The Draw
# b'{"marketId":"1.247667433","marketName":"Match Odds","marketStartTime":"2025-09-15T09:30:00.000Z","totalMatched":1.18,"runners":[{"selectionId":424676,"runnerName":"Surrey","handicap":0.0,"sortPriority":1},{"selectionId":2780,"runnerName":"Nottinghamshire","handicap":0.0,"sortPriority":2},{"selectionId":60443,"runnerName":"The Draw","handicap":0.0,"sortPriority":3}],"event":{"id":"34723526","name":"Surrey v Nottinghamshire","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T09:30:00.000Z"}}'
#    424676 Surrey
#    2780 Nottinghamshire
#    60443 The Draw
# b'{"marketId":"1.247693549","marketName":"Match Odds","marketStartTime":"2025-09-15T12:00:00.000Z","totalMatched":264.01,"runners":[{"selectionId":247650,"runnerName":"United Arab Emirates","handicap":0.0,"sortPriority":1},{"selectionId":3786092,"runnerName":"Oman","handicap":0.0,"sortPriority":2}],"event":{"id":"34726583","name":"United Arab Emirates v Oman","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T12:00:00.000Z"}}'
#    247650 United Arab Emirates
#    3786092 Oman
# b'{"marketId":"1.247765255","marketName":"Match Odds","marketStartTime":"2025-09-15T14:30:00.000Z","totalMatched":7.04,"runners":[{"selectionId":7337,"runnerName":"Sri Lanka","handicap":0.0,"sortPriority":1},{"selectionId":247649,"runnerName":"Hong Kong","handicap":0.0,"sortPriority":2}],"event":{"id":"34730278","name":"Sri Lanka v Hong Kong","countryCode":"GB","timezone":"GMT","openDate":"2025-09-15T14:30:00.000Z"}}'
#    7337 Sri Lanka
#    247649 Hong Kong
# b'{"marketId":"1.247605916","marketName":"Match Odds","marketStartTime":"2025-09-16T04:30:00.000Z","totalMatched":145.51,"runners":[{"selectionId":86568597,"runnerName":"Pakistan W","handicap":0.0,"sortPriority":1},{"selectionId":84602355,"runnerName":"South Africa W","handicap":0.0,"sortPriority":2}],"event":{"id":"34715675","name":"Pakistan W v South Africa W","countryCode":"GB","timezone":"GMT","openDate":"2025-09-16T04:30:00.000Z"}}'
#    86568597 Pakistan W
#    84602355 South Africa W
# b'{"marketId":"1.247767716","marketName":"Match Odds","marketStartTime":"2025-09-16T19:00:00.000Z","totalMatched":0.0,"runners":[{"selectionId":47650821,"runnerName":"Barbados Royals Women","handicap":0.0,"sortPriority":1},{"selectionId":47860173,"runnerName":"Trinbago Knight Riders W","handicap":0.0,"sortPriority":2}],"event":{"id":"34733954","name":"Barbados Royals Women v Trinbago Knight Riders W","countryCode":"GB","timezone":"GMT","openDate":"2025-09-16T19:00:00.000Z"}}'
#    47650821 Barbados Royals Women
#    47860173 Trinbago Knight Riders W
# b'{"marketId":"1.247342564","marketName":"Match Odds","marketStartTime":"2025-09-20T10:00:00.000Z","totalMatched":12.88,"runners":[{"selectionId":3961,"runnerName":"Hampshire","handicap":0.0,"sortPriority":1},{"selectionId":31372,"runnerName":"Worcestershire","handicap":0.0,"sortPriority":2}],"event":{"id":"34687626","name":"Hampshire v Worcestershire","countryCode":"GB","timezone":"GMT","openDate":"2025-09-20T10:00:00.000Z"}}'
#    3961 Hampshire
#    31372 Worcestershire
# GB 142
# OM 3
# AU 16
# IN 1
# STDOUT: 2025-09-14 12:47:33,716 INFO ::  Processing closed market: None, 1.247721182
# STDOUT: 2025-09-14 12:47:33,718 WARNING ::  Total pnl for market:None, 1.247721182, : PNL :: 0.0
# STDOUT: 2025-09-14 12:47:33,719 INFO ::  Processing closed market: None, 1.247721183
# STDOUT: 2025-09-14 12:47:33,720 WARNING ::  Total pnl for market:None, 1.247721183, : PNL :: 0.0
# STDOUT: 2025-09-14 12:47:33,721 INFO ::  Processing closed market: None, 1.247721184
# STDOUT: 2025-09-14 12:47:33,722 WARNING ::  Total pnl for market:None, 1.247721184, : PNL :: 0.0
# STDOUT: 2025-09-14 12:47:33,724 INFO ::  Processing closed market: None, 1.247589864
# STDOUT: 2025-09-14 12:47:33,724 WARNING ::  Total pnl for market:None, 1.247589864, : PNL :: 0.0
# STDOUT: 2025-09-14 12:47:33,725 INFO ::  Processing closed market: None, 1.247721181
# STDOUT: 2025-09-14 12:47:33,727 WARNING ::  Total pnl for market:None, 1.247721181, : PNL :: 0.0
# STDOUT: 2025-09-14 12:47:33,728 INFO ::  Processing closed market: None, 1.247721180
# STDOUT: 2025-09-14 12:47:33,728 WARNING ::  Total pnl for market:None, 1.247721180, : PNL :: 0.0
# STDOUT: 2025-09-14 12:51:24,493 INFO ::  Processing closed market: Glamorgan W v Yorkshire W, 1.247589863
# STDOUT: 2025-09-14 12:51:24,494 WARNING ::  Total pnl for market:Glamorgan W v Yorkshire W, 1.247589863, : PNL :: 0.0
# STDOUT: 2025-09-14 12:51:39,455 INFO ::  Processing closed market: Glamorgan W v Yorkshire W, 1.247589862
# STDOUT: 2025-09-14 12:51:39,456 INFO ::  Order PNL 0.0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2025-09-14 11:47:14
# STDOUT: 2025-09-14 12:51:39,458 INFO ::  Order PNL 0.0, av size matched: 0.0 av price matched: 0.0, date_time_created: 2025-09-14 11:34:25
# STDOUT: 2025-09-14 12:51:39,459 WARNING ::  Total pnl for market:Glamorgan W v Yorkshire W, 1.247589862, : PNL :: 0.0
# STDOUT: 2025-09-14 12:52:10,550 INFO ::  Processing closed market: None, 1.247590013
# STDOUT: 2025-09-14 12:52:10,551 WARNING ::  Total pnl for market:None, 1.247590013, : PNL :: 0.0
# STDOUT: 2025-09-14 12:56:11,933 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 12:56:11,936 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 12:56:34,975 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 12:56:34,977 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:01:14,697 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:01:14,702 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:01:37,657 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:01:37,659 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:21:33,479 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:21:33,485 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:23:16,734 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:23:16,736 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:45:35,239 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:45:35,243 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:46:17,134 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:46:17,136 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:46:26,331 INFO ::  Processing closed market: India W v Australia W, 1.247721231
# STDOUT: 2025-09-14 13:46:26,333 WARNING ::  Total pnl for market:India W v Australia W, 1.247721231, : PNL :: 0.0
# STDOUT: 2025-09-14 13:46:39,745 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:46:39,748 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:47:02,899 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:47:02,901 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:47:25,577 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:47:25,579 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:51:19,211 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:51:19,216 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:51:41,955 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:51:41,957 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:52:04,753 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:52:04,757 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:52:27,411 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:52:27,414 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:52:50,081 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:52:50,083 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:53:19,511 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:53:19,513 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:53:42,328 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:53:42,330 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 13:54:05,020 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 13:54:05,023 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:00:56,056 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 14:00:56,064 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.02, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:01:45,919 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 14:01:45,922 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:02:08,825 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 14:02:08,827 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:02:44,174 INFO ::  price less than thresh, no live trades, placing order: 10987516
# STDOUT: 2025-09-14 14:02:44,176 INFO ::  {'PLACE ORDER': '1.247721170', 'price': 1.2, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:02:58,969 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 14:02:58,971 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:03:07,342 INFO ::  price less than thresh, no live trades, placing order: 10987516
# STDOUT: 2025-09-14 14:03:07,344 INFO ::  {'PLACE ORDER': '1.247721170', 'price': 1.19, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:03:13,744 INFO ::  price less than thresh, no live trades, placing order: 10987516
# STDOUT: 2025-09-14 14:03:13,746 INFO ::  {'PLACE ORDER': '1.247721170', 'price': 1.23, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:03:21,611 INFO ::  price less than thresh, no live trades, placing order: 37302
# STDOUT: 2025-09-14 14:03:21,613 INFO ::  {'PLACE ORDER': '1.247721171', 'price': 1.03, 'event_name': 'India W v Australia W'}
# STDOUT: 2025-09-14 14:03:37,104 INFO ::  price less than thresh, no live trades, placing order: 10987516
# STDOUT: 2025-09-14 14:03:37,107 INFO ::  {'PLACE ORDER': '1.247721170', 'price': 1.2, 'event_name': 'India W v Australia W'}
